# %% [markdown]
# <a href="https://colab.research.google.com/github/Ehizson/Derekmano/blob/main/Derek_June_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***DEREK-MANO LUXURY***

# %% [markdown]
# **June Sales Comprehensive Report**

# %%
# importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load dataset

df = pd.read_csv('/content/June_24 Sales.csv')
df.head()
# Out:
#        Date    Name Source   Location Av/OO  Qty  Size Description      SP  \
# 0  1/6/2024  Phinex     IG      Lekki    Av  2.0   NaN         118  36,000
# 1  1/6/2024  Phinex     IG      Lekki    OO  1.0  43.0         125  19,000
# 2  1/6/2024   Nexxa     IG  Sangotedo    OO  1.0  45.0         104  20,000
# 3  1/6/2024  Chisom     IG      Abule    OO  1.0  43.0         108  19,000
# 4  1/6/2024  Henrae     IG  Sangotedo    OO  1.0  44.0         104  20,000
#
#        CP  Profit
# 0  21,040  14,960
# 1  11,475   7,525
# 2  11,475   8,525
# 3  11,475   7,525
# 4  11,475   8,525

# %%
df.shape
# Out:
# (239, 11)

# %%
# Remove commas from the strings and convert to int
df['CP'] = df['CP'].str.replace(',', '').astype(float).fillna(0).astype(int) # Fill NaN with 0 then convert to int
df['Profit'] = df['Profit'].str.replace(',', '').astype(float).fillna(0).astype(int) # Fill NaN with 0 then convert to int

# Convert float column to object
df['Size'] = df['Size'].astype(object)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         193 non-null    object
#  1   Name         193 non-null    object
#  2   Source       193 non-null    object
#  3   Location     182 non-null    object
#  4   Av/OO        193 non-null    object
#  5   Qty          193 non-null    float64
#  6   Size         188 non-null    object
#  7   Description  193 non-null    object
#  8   SP           193 non-null    object
#  9   CP           239 non-null    int64
#  10  Profit       239 non-null    int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 20.7+ KB

# %% [markdown]
# **Exploratory Data Analysis**

# %%
# Location Counts

count = df['Location'].value_counts()
print(count)
# Out:
# Location
# Abuja        20
# Ago          11
# Lekki        10
# Ajah          7
# PH            7
# Ibadan        6
# Asaba         6
# Airport       6
# Surulere      6
# Abule         6
# Sangotedo     6
# Pick up       5
# Festac        4
# TF            4
# Benin         4
# Ikeja         4
# Umuahia       3
# Osogbo        3
# Ikotun        3
# Apapa         3
# Yaba          3
# Ikorodu       3
# Ota           3
# Shogunle      2
# Ilorin        2
# Owerri        2
# Awka          2
# Ondo          2
# Abeokuta      2
# Anthony       2
# Akure         2
# Ugheli        2
# Ogun          2
# Mowe          2
# Gbagada       2
# Ogba          1
# Iyana         1
# Ebute         1
# Fadeyi        1
# Ishaga        1
# Ojodu         1
# Ikate         1
# Pickup        1
# Ogudu         1
# Bariga        1
# Onitsha       1
# Tf            1
# Kano          1
# Warri         1
# Agbor         1
# Ikoyi         1
# VI            1
# TBS           1
# Ejigbo        1
# ...

# %% [markdown]
# Abuja, Ago & Lekki was where we had the majority of orders delivered.

# %%
# pie-chart

brand = df['Description'].value_counts()
plt.pie(brand, labels = brand.index, autopct = '%0.0f%%')

plt.show()

# %% [markdown]
# Illustrated by the diagram above, the top 3 most sold items are as follows :
# * 104
# * LIG
# * 133
# * 125

# %%
# Numbers sold by each brand

df['Description'].value_counts()
# Out:
# Description
# 104    89
# LIG    13
# 133    12
# 125     8
# 109     6
# 119     6
# 141     5
# 101     5
# 149     4
# 129     4
# 142     4
# 120     4
# 112     3
# 108     3
# 118     3
# 102     2
# 106     2
# 131     2
# 116     2
# 114     2
# 139     2
# 105     2
# 128     2
# 111     1
# 145     1
# 134     1
# 117     1
# 148     1
# 130     1
# 132     1
# 124     1
# Name: count, dtype: int64

# %% [markdown]
# Further information on the top 3 most sold items by the information above:
#
# * 104 - 89 pairs were sold
# * LIG - 13 pairs were sold
# * 133 - 12 pairs were sold
# * 125 - 8 pairs were sold

# %%
# bar chart
brand = df['Description'].value_counts()

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Description')

plt.xlabel('Brand')
plt.ylabel('Count')
plt.title('Brand Counts')

plt.xticks(rotation=90)
plt.show()

# %%
# Numbers sold in sizes

count = df['Size'].value_counts()
print(count)
# Out:
# Size
# 43.0    46
# 44.0    39
# 45.0    36
# 42.0    27
# 46.0    13
# 41.0    10
# 47.0     6
# 40.0     5
# 48.0     4
# 38.0     2
# Name: count, dtype: int64

# %% [markdown]
# The top 3 most sold items in terms of sizes are:
#
# * 43
# * 45
# * 44

# %%
# bar chart
brand = df['Size'].value_counts()

plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Size')

plt.xlabel('Size')
plt.ylabel('Count')
plt.title('Size Counts')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# **Size Allocation Visualization**

# %% [markdown]
# * **Size 48**

# %%
# Filter the DataFrame to get rows where 'Size' column is 48
size_48_df = df[df['Size'] == 48]

# Get the counts of each unique value in the 'Description' column in the filtered DataFrame
description_counts = size_48_df['Description'].value_counts()

# Plot the counts using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=description_counts.index, y=description_counts.values)

plt.xlabel('Description')
plt.ylabel('Count')
plt.title('Description Counts for Size 48')

plt.xticks(rotation=90)
plt.show()

# %%
# Filter the DataFrame to get rows where 'Size' column is 48
size_48_df = df[df['Size'] == 48]

# Get the counts of each unique value in the 'Description' column where 'Size' is 48
description_counts_in_size_48 = size_48_df['Description'].value_counts()

print(description_counts_in_size_48)
# Out:
# Description
# 108    1
# 104    1
# LIG    1
# 116    1
# Name: count, dtype: int64

# %% [markdown]
# * **Size 47**

# %%
# Filter the DataFrame to get rows where 'Size' column is 47
size_47_df = df[df['Size'] == 47]

# Get the counts of each unique value in the 'Description' column in the filtered DataFrame
description_counts = size_47_df['Description'].value_counts()

# Plot the counts using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=description_counts.index, y=description_counts.values)

plt.xlabel('Description')
plt.ylabel('Count')
plt.title('Description Counts for Size 47')

plt.xticks(rotation=90)
plt.show()

# %%
# Filter the DataFrame to get rows where 'Size' column is 47
size_47_df = df[df['Size'] == 47]

# Get the counts of each unique value in the 'Description' column where 'Size' is 47
description_counts_in_size_47 = size_47_df['Description'].value_counts()

print(description_counts_in_size_47)
# Out:
# Description
# 104    2
# 133    1
# 112    1
# LIG    1
# 120    1
# Name: count, dtype: int64

# %% [markdown]
# * **Size 46**

# %%
# Filter the DataFrame to get rows where 'Size' column is 46
size_46_df = df[df['Size'] == 46]

# Get the counts of each unique value in the 'Description' column in the filtered DataFrame
description_counts = size_46_df['Description'].value_counts()

# Plot the counts using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=description_counts.index, y=description_counts.values)

plt.xlabel('Description')
plt.ylabel('Count')
plt.title('Description Counts for Size 46')

plt.xticks(rotation=90)
plt.show()

# %%
# Filter the DataFrame to get rows where 'Size' column is 46
size_46_df = df[df['Size'] == 46]

# Get the counts of each unique value in the 'Description' column where 'Size' is 46
description_counts_in_size_46 = size_46_df['Description'].value_counts()

print(description_counts_in_size_46)
# Out:
# Description
# 104    8
# 141    3
# 119    1
# 149    1
# Name: count, dtype: int64

# %% [markdown]
# * **Size 45**

# %%
# Filter the DataFrame to get rows where 'Size' column is 45
size_45_df = df[df['Size'] == 45]

# Get the counts of each unique value in the 'Description' column in the filtered DataFrame
description_counts = size_45_df['Description'].value_counts()

# Plot the counts using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=description_counts.index, y=description_counts.values)

plt.xlabel('Description')
plt.ylabel('Count')
plt.title('Description Counts for Size 45')

plt.xticks(rotation=90)
plt.show()

# %%
# Filter the DataFrame to get rows where 'Size' column is 45
size_45_df = df[df['Size'] == 45]

# Get the counts of each unique value in the 'Description' column where 'Size' is 45
description_counts_in_size_45 = size_45_df['Description'].value_counts()

print(description_counts_in_size_45)
# Out:
# Description
# 104    21
# 133     3
# 101     2
# 112     2
# 109     2
# 149     2
# 139     1
# LIG     1
# 114     1
# 119     1
# Name: count, dtype: int64

# %% [markdown]
# * **Size 44**

# %%
# Filter the DataFrame to get rows where 'Size' column is 44
size_44_df = df[df['Size'] == 44]

# Get the counts of each unique value in the 'Description' column in the filtered DataFrame
description_counts = size_44_df['Description'].value_counts()

# Plot the counts using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=description_counts.index, y=description_counts.values)

plt.xlabel('Description')
plt.ylabel('Count')
plt.title('Description Counts for Size 44')

plt.xticks(rotation=90)
plt.show()

# %%
# Filter the DataFrame to get rows where 'Size' column is 44
size_44_df = df[df['Size'] == 44]

# Get the counts of each unique value in the 'Description' column where 'Size' is 44
description_counts_in_size_44 = size_44_df['Description'].value_counts()

print(description_counts_in_size_44)
# Out:
# Description
# 104    21
# 125     2
# 141     2
# 133     2
# 131     2
# 128     1
# 148     1
# 105     1
# 106     1
# 120     1
# LIG     1
# 139     1
# 101     1
# 108     1
# 129     1
# Name: count, dtype: int64

# %% [markdown]
# * **Size 43**

# %%
# Filter the DataFrame to get rows where 'Size' column is 43
size_43_df = df[df['Size'] == 43]

# Get the counts of each unique value in the 'Description' column in the filtered DataFrame
description_counts = size_43_df['Description'].value_counts()

# Plot the counts using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=description_counts.index, y=description_counts.values)

plt.xlabel('Description')
plt.ylabel('Count')
plt.title('Description Counts for Size 43')

plt.xticks(rotation=90)
plt.show()

# %%
# Filter the DataFrame to get rows where 'Size' column is 43
size_43_df = df[df['Size'] == 43]

# Get the counts of each unique value in the 'Description' column where 'Size' is 43
description_counts_in_size_43 = size_43_df['Description'].value_counts()

print(description_counts_in_size_43)
# Out:
# Description
# 104    16
# LIG     7
# 109     3
# 125     2
# 120     2
# 119     2
# 106     1
# 101     1
# 128     1
# 129     1
# 133     1
# 142     1
# 116     1
# 149     1
# 108     1
# 111     1
# 114     1
# 105     1
# 134     1
# 124     1
# Name: count, dtype: int64

# %% [markdown]
# * **Size 42**

# %%
# Filter the DataFrame to get rows where 'Size' column is 42
size_42_df = df[df['Size'] == 42]

# Get the counts of each unique value in the 'Description' column in the filtered DataFrame
description_counts = size_42_df['Description'].value_counts()

# Plot the counts using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=description_counts.index, y=description_counts.values)

plt.xlabel('Description')
plt.ylabel('Count')
plt.title('Description Counts for Size 42')

plt.xticks(rotation=90)
plt.show()

# %%
# Filter the DataFrame to get rows where 'Size' column is 42
size_42_df = df[df['Size'] == 42]

# Get the counts of each unique value in the 'Description' column where 'Size' is 42
description_counts_in_size_42 = size_42_df['Description'].value_counts()

print(description_counts_in_size_42)
# Out:
# Description
# 104    11
# 133     4
# 129     2
# 142     2
# 125     2
# 109     1
# LIG     1
# 145     1
# 102     1
# 132     1
# 119     1
# Name: count, dtype: int64

# %% [markdown]
# * **Size 41**

# %%
# Filter the DataFrame to get rows where 'Size' column is 41
size_41_df = df[df['Size'] == 41]

# Get the counts of each unique value in the 'Description' column in the filtered DataFrame
description_counts = size_41_df['Description'].value_counts()

# Plot the counts using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=description_counts.index, y=description_counts.values)

plt.xlabel('Description')
plt.ylabel('Count')
plt.title('Description Counts for Size 41')

plt.xticks(rotation=90)
plt.show()

# %%
# Filter the DataFrame to get rows where 'Size' column is 41
size_41_df = df[df['Size'] == 41]

# Get the counts of each unique value in the 'Description' column where 'Size' is 41
description_counts_in_size_41 = size_41_df['Description'].value_counts()

print(description_counts_in_size_41)
# Out:
# Description
# 104    5
# 101    1
# 102    1
# 119    1
# 142    1
# 133    1
# Name: count, dtype: int64

# %% [markdown]
# * **Size 40**

# %%
# Filter the DataFrame to get rows where 'Size' column is 40
size_40_df = df[df['Size'] == 40]

# Get the counts of each unique value in the 'Description' column in the filtered DataFrame
description_counts = size_40_df['Description'].value_counts()

# Plot the counts using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=description_counts.index, y=description_counts.values)

plt.xlabel('Description')
plt.ylabel('Count')
plt.title('Description Counts for Size 40')

plt.xticks(rotation=90)
plt.show()

# %%
# Filter the DataFrame to get rows where 'Size' column is 40
size_40_df = df[df['Size'] == 40]

# Get the counts of each unique value in the 'Description' column where 'Size' is 40
description_counts_in_size_40 = size_40_df['Description'].value_counts()

print(description_counts_in_size_40)
# Out:
# Description
# 104    3
# LIG    1
# 125    1
# Name: count, dtype: int64

# %% [markdown]
# * **Size 39**

# %%
# Filter the DataFrame to get rows where 'Size' column is 39
size_39_df = df[df['Size'] == 39]

# Get the counts of each unique value in the 'Description' column in the filtered DataFrame
description_counts = size_39_df['Description'].value_counts()

# Plot the counts using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=description_counts.index, y=description_counts.values)

plt.xlabel('Description')
plt.ylabel('Count')
plt.title('Description Counts for Size 39')

plt.xticks(rotation=90)
plt.show()

# %%
# Filter the DataFrame to get rows where 'Size' column is 39
size_39_df = df[df['Size'] == 39]

# Get the counts of each unique value in the 'Description' column where 'Size' is 39
description_counts_in_size_39 = size_39_df['Description'].value_counts()

print(description_counts_in_size_39)
# Out:
# Series([], Name: count, dtype: int64)

# %%
# Inventory availability

count = df['Av/OO'].value_counts()
print(count)
# Out:
# Av/OO
# OO    164
# Av     29
# Name: count, dtype: int64

# %%
count = df['Source'].value_counts()
print(count)
# Out:
# Source
# IG    155
# WA     38
# Name: count, dtype: int64

# %%
# total sum of sold items

df['Qty'].sum()
# Out:
# 235.0

# %% [markdown]
# The month of June recorded a total sale of 235 items

# %%
# total cost production

df['CP'].sum()
# Out:
# 2699820

# %% [markdown]
# The Total Cost Production of sold items in the month of June is N2,699,820

# %%
# total profit realized

df['Profit'].sum()
# Out:
# 1901655

# %% [markdown]
# Total Profit realized in the month of June is N1,901,655
